# %% [markdown]
# ## FITNESS Chatbot

# %% [markdown]
# ## The Fitness Chatbot is a recommender system that provides personalized recommendations for fitness enthusiasts. The chatbot uses machine learning algorithms to analyze user data, such as their fitness goals, dietary preferences, and exercise history, to provide tailored recommendations on workouts, nutrition, and supplements.

# %%
import csv
import pandas as pd

# %%
# Define user registration form
def registration_form():
    # Ask user to provide basic details
    name = input("What is your name?")
    age = input("What is your age?")
    gender = input("What is your gender?")
    weight = int(input("What is your weight (in kg)?"))
    height = int(input("What is your height (in cm)?"))
    email = input("What is your email address?")

# %%
with open('user_data.csv',mode='w',newline='')as user_file:
    fieldnames =['Name','Age','Gender','Weight','Height','Email']
    writer =csv.DictWriter(user_file,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({'Name':'name','Age':'age','Gender':'gender','Weight':'weight',
                    'Height':'height','Email':'email'})

# %%
user_data = pd.read_csv("people_dataset.csv")

# %%
workout = pd.read_csv("workout_user_dataset.csv")

# %%
# Import necessary libraries
import pandas as pd
from sklearn.cluster import KMeans

# %%
# Define clustering algorithm
kmeans = KMeans(n_clusters=3)

# Fit the algorithm on the user data
kmeans.fit(user_data[['Age', 'Weight_KG', 'Height_CM']])

# Get the labels for each user
labels = kmeans.labels_

# Print the label for each user
for i in range(len(user_data)):
    print(f"{user_data['Name'][i]} belongs to cluster {labels[i]}")
# Out:
# C:\Users\91772\anconda\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91772\anconda\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Sydney Molina belongs to cluster 1
# Amy Huang belongs to cluster 0
# Jonathan Rowe belongs to cluster 1
# James Randolph belongs to cluster 2
# Leslie Lang belongs to cluster 0
# Michael Nelson belongs to cluster 1
# Jimmy Johnson belongs to cluster 1
# Mary Graham belongs to cluster 2
# Angela Lewis belongs to cluster 2
# Steven Hoffman belongs to cluster 1
# Anna Clark belongs to cluster 0
# Michael Weber belongs to cluster 1
# Taylor Marsh belongs to cluster 0
# Stephanie Marshall belongs to cluster 0
# Kyle Christensen belongs to cluster 2
# Larry Rogers belongs to cluster 1
# Wanda Walker belongs to cluster 2
# Ashley Hahn belongs to cluster 0
# Lisa Adams belongs to cluster 1
# John Carroll belongs to cluster 1
# Daniel Wallace belongs to cluster 2
# Corey Taylor belongs to cluster 2
# Thomas Young belongs to cluster 1
# Karen Davenport belongs to cluster 0
# Laura Prince belongs to cluster 2
# Danielle Brown belongs to cluster 0
# Joshua Nicholson belongs to cluster 0
# Howard Acosta belongs to cluster 2
# Ronald Hamilton belongs to cluster 0
# Joel Nelson belongs to cluster 1
# Dawn Smith belongs to cluster 0
# Mr. Joseph Stone MD belongs to cluster 2
# Paul Lopez belongs to cluster 1
# Tina Goodwin belongs to cluster 1
# Kristin Patrick belongs to cluster 1
# Tony Deleon belongs to cluster 2
# Joshua Weber belongs to cluster 2
# Timothy Phillips belongs to cluster 2
# Charlotte Baird belongs to cluster 2
# Michael Williams belongs to cluster 1
# Stanley Fitzgerald belongs to cluster 1
# Jill Henry belongs to cluster 1
# Daniel Perez belongs to cluster 1
# Jason Webb belongs to cluster 0
# Shawn Murray belongs to cluster 2
# Mike Harris belongs to cluster 1
# Lawrence Decker belongs to cluster 1
# Lisa Torres belongs to cluster 0
# Chad Franco belongs to cluster 2
# Ashley Zamora belongs to cluster 0
# Deborah Carlson belongs to cluster 2
# Rachel English belongs to cluster 1
# Andrea Sanchez belongs to cluster 1
# Carla Evans belongs to cluster 1
# Lindsay Richardson belongs to cluster 0
# Cassidy Patel belongs to cluster 0
# Gloria Frey belongs to cluster 2
# Deborah Whitehead belongs to cluster 2
# Elizabeth Hughes belongs to cluster 1
# Michael Rogers belongs to cluster 1
# Pamela Miller belongs to cluster 2
# Rachel Barrett belongs to cluster 2
# Lisa Vega belongs to cluster 0
# Michael Lee belongs to cluster 2
# Thomas Vaughn belongs to cluster 1
# Jesse Torres belongs to cluster 1
# Gregory Soto belongs to cluster 1
# Heidi Curtis belongs to cluster 0
# Sharon Nelson belongs to cluster 2
# Deborah Stewart belongs to cluster 0
# Sean Bowman belongs to cluster 1
# Michael Davis belongs to cluster 2
# Robert Peters belongs to cluster 0
# Daniel Clarke belongs to cluster 0
# Carmen Christensen belongs to cluster 1
# Melissa Wells belongs to cluster 1
# Malik Tran belongs to cluster 1
# Katie Calhoun belongs to cluster 0
# Amanda Hernandez belongs to cluster 1
# Brian Price belongs to cluster 0
# Marie Beasley belongs to cluster 1
# Michelle Harris belongs to cluster 2
# Charles Schwartz belongs to cluster 1
# William Sparks belongs to cluster 0
# Amber Gibson belongs to cluster 2
# Lindsay Watson belongs to cluster 2
# Derek Jones belongs to cluster 2
# Oscar Reed belongs to cluster 0
# Nathan Freeman belongs to cluster 0
# Zachary Vance belongs to cluster 2
# Natalie Pollard belongs to cluster 0
# Brett Daniels belongs to cluster 2
# Ashley Acosta belongs to cluster 2
# Faith Bird belongs to cluster 2
# Laurie Cervantes belongs to cluster 2
# Kevin Reynolds belongs to cluster 0
# Jill Cohen belongs to cluster 2
# David Potter belongs to cluster 0
# Miranda Castillo belongs to cluster 0
# Cynthia Burton belongs to cluster 1

# %%
# Import necessary libraries
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        100 non-null    object
#  1   Age         100 non-null    int64
#  2   Weight_KG   100 non-null    int64
#  3   Height_CM   100 non-null    int64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 4.0+ KB

# %%
workout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   User_Age              100 non-null    int64
#  1   User_Weight_KG        100 non-null    int64
#  2   User_Height_CM        100 non-null    int64
#  3   Workout_Type          100 non-null    object
#  4   Workout_Duration_Min  100 non-null    int64
#  5   Workout_Intensity     100 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
# Calculate the cosine similarity between user data and workout data
cosine_sim = cosine_similarity(user_data[['Age', 'Weight_KG', 'Height_CM']], workout[['User_Age', 'User_Weight_KG', 'User_Height_CM']])

# %%
# Get the top 5 recommended workouts for each user
for i in range(len(user_data)):
    sim_scores = list(enumerate(cosine_sim[i]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6]
    workout_indices = [i[0] for i in sim_scores]
    print(f"Top 5 recommended workouts for {user_data['Name'][i]} are:")
    print(workout['Workout_Duration_Min'][workout_indices])
# Out:
# Top 5 recommended workouts for Sydney Molina are:
# 7     11
# 13    77
# 19    57
# 1     12
# 53    60
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Amy Huang are:
# 96    10
# 58    38
# 31    52
# 28    37
# 48    87
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Jonathan Rowe are:
# 15    32
# 94    65
# 38    70
# 33    27
# 50    85
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for James Randolph are:
# 45    64
# 20    18
# 5     87
# 92    18
# 6     24
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Leslie Lang are:
# 37    37
# 31    52
# 28    37
# 69    56
# 96    10
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michael Nelson are:
# 66    88
# 40    70
# 72    72
# 82    37
# 87    72
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Jimmy Johnson are:
# 48    87
# 96    10
# 30    34
# 26    63
# 56    52
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Mary Graham are:
# 18    45
# 86    88
# 17    76
# 6     24
# 5     87
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Angela Lewis are:
# 92    18
# 84    51
# 65    27
# 20    18
# 3     83
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Steven Hoffman are:
# 30    34
# 48    87
# 96    10
# 56    52
# 26    63
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Anna Clark are:
# 80    90
# 61    68
# 36    82
# 34    40
# 53    60
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michael Weber are:
# 2     11
# 71    13
# 23    51
# 13    77
# 7     11
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Taylor Marsh are:
# 41    58
# 14    66
# 29    68
# 6     24
# 28    37
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Stephanie Marshall are:
# 56    52
# 94    65
# 38    70
# 43    54
# 30    34
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Kyle Christensen are:
# 6     24
# 5     87
# 57    47
# 51    69
# 14    66
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Larry Rogers are:
# 15    32
# 43    54
# 94    65
# 38    70
# 88    10
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Wanda Walker are:
# 20    18
# 92    18
# 45    64
# 5     87
# 25    49
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Ashley Hahn are:
# 61    68
# 70    78
# 34    40
# 59    86
# 99    31
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Lisa Adams are:
# 19    57
# 80    90
# 54    52
# 7     11
# 95    11
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for John Carroll are:
# 82    37
# 33    27
# 97    52
# 72    72
# 40    70
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Daniel Wallace are:
# 35    15
# 44    27
# 92    18
# 90    52
# 20    18
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Corey Taylor are:
# 86    88
# 55    64
# 62    25
# 5     87
# 18    45
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Thomas Young are:
# 99    31
# 77    67
# 59    86
# 8     79
# 85    44
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Karen Davenport are:
# 53    60
# 80    90
# 19    57
# 10    87
# 54    52
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Laura Prince are:
# 25    49
# 11    37
# 20    18
# 89    24
# 51    69
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Danielle Brown are:
# 31    52
# 14    66
# 26    63
# 96    10
# 79    88
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Joshua Nicholson are:
# 70    78
# 59    86
# 61    68
# 99    31
# 80    90
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Howard Acosta are:
# 92    18
# 20    18
# 11    37
# 44    27
# 25    49
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Ronald Hamilton are:
# 37    37
# 31    52
# 28    37
# 69    56
# 48    87
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Joel Nelson are:
# 16    32
# 33    27
# 97    52
# 72    72
# 40    70
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Dawn Smith are:
# 50    85
# 47    77
# 94    65
# 38    70
# 68    33
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Mr. Joseph Stone MD are:
# 74    67
# 52    63
# 22    23
# 60    85
# 81    64
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Paul Lopez are:
# 98    19
# 87    72
# 40    70
# 72    72
# 27    67
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Tina Goodwin are:
# 49    13
# 21    88
# 67    18
# 47    77
# 63    82
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Kristin Patrick are:
# 94    65
# 15    32
# 68    33
# 43    54
# 56    52
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Tony Deleon are:
# 5     87
# 17    76
# 51    69
# 41    58
# 45    64
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Joshua Weber are:
# 45    64
# 5     87
# 20    18
# 92    18
# 6     24
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Timothy Phillips are:
# 6     24
# 5     87
# 55    64
# 45    64
# 18    45
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Charlotte Baird are:
# 62    25
# 60    85
# 81    64
# 55    64
# 18    45
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michael Williams are:
# 21    88
# 13    77
# 1     12
# 2     11
# 71    13
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Stanley Fitzgerald are:
# 96    10
# 26    63
# 48    87
# 30    34
# 31    52
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Jill Henry are:
# 88    10
# 68    33
# 50    85
# 49    13
# 38    70
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Daniel Perez are:
# 47    77
# 27    67
# 9     61
# 21    88
# 91    40
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Jason Webb are:
# 85    44
# 99    31
# 0     50
# 73    39
# 76    80
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Shawn Murray are:
# 60    85
# 81    64
# 86    88
# 74    67
# 52    63
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Mike Harris are:
# 96    10
# 58    38
# 31    52
# 48    87
# 28    37
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Lawrence Decker are:
# 21    88
# 1     12
# 13    77
# 83    83
# 54    52
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Lisa Torres are:
# 8     79
# 85    44
# 70    78
# 12    47
# 0     50
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Chad Franco are:
# 5     87
# 17    76
# 51    69
# 45    64
# 41    58
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Ashley Zamora are:
# 0     50
# 64    44
# 8     79
# 75    56
# 99    31
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Deborah Carlson are:
# 5     87
# 17    76
# 51    69
# 41    58
# 45    64
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Rachel English are:
# 91    40
# 27    67
# 1     12
# 54    52
# 9     61
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Andrea Sanchez are:
# 98    19
# 87    72
# 40    70
# 72    72
# 82    37
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Carla Evans are:
# 39    82
# 46    46
# 32    84
# 10    87
# 91    40
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Lindsay Richardson are:
# 80    90
# 36    82
# 10    87
# 53    60
# 19    57
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Cassidy Patel are:
# 64    44
# 79    88
# 75    56
# 85    44
# 0     50
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Gloria Frey are:
# 84    51
# 74    67
# 22    23
# 52    63
# 78    71
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Deborah Whitehead are:
# 14    66
# 29    68
# 6     24
# 5     87
# 57    47
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Elizabeth Hughes are:
# 16    32
# 97    52
# 72    72
# 98    19
# 40    70
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michael Rogers are:
# 15    32
# 94    65
# 38    70
# 33    27
# 50    85
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Pamela Miller are:
# 92    18
# 84    51
# 20    18
# 65    27
# 11    37
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Rachel Barrett are:
# 51    69
# 45    64
# 25    49
# 75    56
# 11    37
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Lisa Vega are:
# 21    88
# 9     61
# 2     11
# 13    77
# 67    18
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michael Lee are:
# 86    88
# 81    64
# 60    85
# 18    45
# 55    64
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Thomas Vaughn are:
# 49    13
# 38    70
# 94    65
# 63    82
# 67    18
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Jesse Torres are:
# 30    34
# 48    87
# 58    38
# 96    10
# 26    63
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Gregory Soto are:
# 40    70
# 47    77
# 66    88
# 72    72
# 88    10
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Heidi Curtis are:
# 37    37
# 28    37
# 31    52
# 29    68
# 14    66
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Sharon Nelson are:
# 92    18
# 35    15
# 44    27
# 20    18
# 11    37
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Deborah Stewart are:
# 32    84
# 95    11
# 53    60
# 19    57
# 80    90
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Sean Bowman are:
# 88    10
# 50    85
# 68    33
# 40    70
# 72    72
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michael Davis are:
# 86    88
# 17    76
# 18    45
# 62    25
# 60    85
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Robert Peters are:
# 59    86
# 24    10
# 79    88
# 77    67
# 23    51
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Daniel Clarke are:
# 24    10
# 71    13
# 23    51
# 13    77
# 7     11
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Carmen Christensen are:
# 97    52
# 88    10
# 15    32
# 43    54
# 94    65
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Melissa Wells are:
# 46    46
# 39    82
# 32    84
# 10    87
# 91    40
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Malik Tran are:
# 88    10
# 68    33
# 50    85
# 21    88
# 49    13
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Katie Calhoun are:
# 32    84
# 95    11
# 53    60
# 19    57
# 93    23
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Amanda Hernandez are:
# 30    34
# 48    87
# 58    38
# 96    10
# 26    63
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Brian Price are:
# 90    52
# 73    39
# 44    27
# 8     79
# 85    44
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Marie Beasley are:
# 70    78
# 8     79
# 85    44
# 59    86
# 77    67
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Michelle Harris are:
# 5     87
# 41    58
# 17    76
# 51    69
# 57    47
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Charles Schwartz are:
# 39    82
# 93    23
# 87    72
# 66    88
# 32    84
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for William Sparks are:
# 14    66
# 57    47
# 28    37
# 51    69
# 75    56
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Amber Gibson are:
# 6     24
# 5     87
# 55    64
# 45    64
# 51    69
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Lindsay Watson are:
# 65    27
# 84    51
# 92    18
# 3     83
# 20    18
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Derek Jones are:
# 52    63
# 74    67
# 78    71
# 4     46
# 84    51
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Oscar Reed are:
# 37    37
# 31    52
# 69    56
# 28    37
# 48    87
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Nathan Freeman are:
# 36    82
# 80    90
# 61    68
# 34    40
# 53    60
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Zachary Vance are:
# 3     83
# 78    71
# 22    23
# 84    51
# 74    67
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Natalie Pollard are:
# 88    10
# 50    85
# 40    70
# 72    72
# 98    19
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Brett Daniels are:
# 74    67
# 52    63
# 22    23
# 60    85
# 81    64
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Ashley Acosta are:
# 55    64
# 18    45
# 62    25
# 60    85
# 81    64
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Faith Bird are:
# 60    85
# 62    25
# 52    63
# 74    67
# 22    23
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Laurie Cervantes are:
# 6     24
# 57    47
# 5     87
# 51    69
# 14    66
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Kevin Reynolds are:
# 24    10
# 70    78
# 59    86
# 37    37
# 69    56
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Jill Cohen are:
# 92    18
# 20    18
# 45    64
# 84    51
# 86    88
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for David Potter are:
# 14    66
# 51    69
# 57    47
# 75    56
# 89    24
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Miranda Castillo are:
# 96    10
# 58    38
# 31    52
# 28    37
# 48    87
# Name: Workout_Duration_Min, dtype: int64
# Top 5 recommended workouts for Cynthia Burton are:
# 56    52
# 48    87
# 69    56
# 63    82
# 67    18
# Name: Workout_Duration_Min, dtype: int64

# %%
from tkinter import *

# %%
pip install get-response
# Out:
# Requirement already satisfied: get-response in c:\users\91772\anconda\lib\site-packages (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for conda: [Errno 2] No such file or directory: 'c:\\users\\91772\\anconda\\lib\\site-packages\\conda-23.7.2.dist-info\\METADATA'
# WARNING: Error parsing requirements for datashader: [Errno 2] No such file or directory: 'c:\\users\\91772\\anconda\\lib\\site-packages\\datashader-0.15.1.dist-info\\METADATA'
# WARNING: Error parsing requirements for h5py: [Errno 2] No such file or directory: 'c:\\users\\91772\\anconda\\lib\\site-packages\\h5py-3.7.0.dist-info\\METADATA'
# WARNING: Error parsing requirements for holoviews: [Errno 2] No such file or directory: 'c:\\users\\91772\\anconda\\lib\\site-packages\\holoviews-1.17.0.dist-info\\METADATA'
# WARNING: Error parsing requirements for spyder-kernels: [Errno 2] No such file or directory: 'c:\\users\\91772\\anconda\\lib\\site-packages\\spyder_kernels-2.4.3.dist-info\\METADATA'
# WARNING: Error parsing requirements for transformers: [Errno 2] No such file or directory: 'c:\\users\\91772\\anconda\\lib\\site-packages\\transformers-4.29.2.dist-info\\METADATA'

# %%
import get_response
import requests

# %%
def send_message(event):
    # Get the message from the user input field
    user_message = user_input.get()
    # Add the message to the chat history
    chat_history.config(state=NORMAL)
    chat_history.insert(END, "You: " + user_message + "\n\n")
    chat_history.config(state=DISABLED)
    chat_history.yview(END)
    # Get the chatbot's response to the message
    bot_response = get_response(user_message)
    # Add the chatbot's response to the chat history
    chat_history.config(state=NORMAL)
    chat_history.insert(END, "Chatbot: " + bot_response + "\n\n")
    chat_history.config(state=DISABLED)
    chat_history.yview(END)
    # Clear the user input field
    user_input.delete(0, END)

# %%
# Create the main window for the chatbot interface
root = Tk()
root.title("Fitness Chatbot")
# Out:
# ''

# %%
# Create the chat history display
chat_history = Text(root, height=20, width=50)
chat_history.config(state=DISABLED)
chat_history.grid(row=0, column=0, columnspan=2, padx=10, pady=10)

# %%
# Create the user input field
user_input = Entry(root, width=50)
user_input.bind("<Return>", send_message)
user_input.grid(row=1, column=0, padx=10, pady=10)

# %%
# Create the send button
send_button = Button(root, text="Send", command=lambda: send_message(None))
send_button.grid(row=1, column=1, padx=10, pady=10)

# %%
# Start the main loop for the chatbot interface
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\91772\anconda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\91772\AppData\Local\Temp\ipykernel_20476\3416374657.py", line 2, in <lambda>
#     send_button = Button(root, text="Send", command=lambda: send_message(None))
#   File "C:\Users\91772\AppData\Local\Temp\ipykernel_20476\127288126.py", line 10, in send_message
#     bot_response = get_response(user_message)
# TypeError: 'module' object is not callable
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\91772\anconda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\91772\AppData\Local\Temp\ipykernel_20476\127288126.py", line 10, in send_message
#     bot_response = get_response(user_message)
# TypeError: 'module' object is not callable
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\91772\anconda\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\91772\AppData\Local\Temp\ipykernel_20476\127288126.py", line 10, in send_message
#     bot_response = get_response(user_message)
# TypeError: 'module' object is not callable
